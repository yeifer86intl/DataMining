# %% [markdown]
# # Technical Challenge ! Custiomers and Orders - The lifeblood of any business!
#
# This notebook depends on two data files: customers.scv and orders.csv. These files are hosted in the cloud (or Github), so for simplicity, we are providing you with the code to download and save the two files in a folder called 'sample_data' which lives within this notebook session (not on your local computer nor Google Drive).
#
# ![sample_data folder in notebook session](https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/images/sample_data_folder.png)
#
# Please execute the first code snippet before moving to the rest of the exercise as this code will import the data from the files for you to be able to execute the rest of the exercise.
#
# Remember as we said in the previous lecture, you have to save this notebook into your Google Drive by going to menu File/Save a Copy In Drive, or clicking in the button "Copy to Drive". This way, you will not lose any work you've done and the file will persist with your latest changes in your Google Drive. Also we recommend you to rename your .ipynb in your Google Drive, so you can easily find it in the future.

# %%
import requests

def import_data_files():
  r = requests.get('https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/data/customers.csv')
  with open('./sample_data/customers.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/data/orders.csv')
  with open('./sample_data/orders.csv', 'wb') as f:
    f.write(r.content)

import_data_files()
print("Customers and orders CSV files have been added './sample_data'")
# Out:
# Customers and orders CSV files have been added './sample_data'

# %% [markdown]
# # Exercise 1: Processing Customers data (difficulty medium)
#
# The sample customer data in 'customers.csv' file has just 5 columns: CustomerId, First Name, Last Name, City and State
#
# ![Data sample](https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/images/customers.png)
#
# We strongly recommend that you complete from the [Prep Course: Intro to Python](https://colab.research.google.com/github/anyoneai/notebooks/blob/main/python3_crash_course.ipynb) the following section:
# - Section 7: File I/O (to understand how to read CSV file)
# - Section 6: For Loop (to navigate the contents of the CSV file)
# - Section 5: Tuples, Lists, and Dictionaries (to manipulate the data of the CSV file)
#
# With this, we hope you can complete this exercise successfully. Although if you want to solve this with libraries or any other way, you are welcome to do it your way.
#
# *Hint:* We advise you to take a look at the data before you start.
# **if you want to manually take a look at the data before you start, please see the content of the data [here](https://github.com/anyoneai/notebooks/blob/main/customers_and_orders/data/customers.csv).
#
# *Hint*: There are many ways to do this exercise you can do your own, although here's some help. You can solve this exercise reading and parsing CSV files, structuring data into dictionaries, and using for loops to navigate the contents
#
# *Hint*: Also, keep in mind that data might not be clean and you might have to figure out how to deal with that data from the code, without having to modify the data source.
#
# Below are the 5 questions you'll have to answer to pass the evaluation:

# %% [markdown]
# **Question 1:** How many customers are in the file?
# (as help, we have added some comments and starter code to help you structure the solution)

# %%
from os.path import exists
import csv

# check if file can be found and open the file
datafile2 = "./sample_data/customers.csv"
if not exists(datafile2):
  raise SystemExit("You should run the first code cell and download the dataset files!")

# customers file is in the sample_data folder and can be opened.
# Using csv reader is one way of dealing with the file
# but it's up to you how you want to proceed
with open(datafile2, 'r') as fl:
  csvreader2 = csv.reader(fl, delimiter=',')

  # loop through the rows and count etc. THE REST IS UP TO YOU!


print("All done!")
# Out:
# All done!

# %%
import pandas as pd

df2 = pd.read_csv(datafile2)

# %%
df.head()
# Out:
#    CustomerID    FirstName      LastName         City State
# 0        6192        Randi    Piedrahita  Canoga Park    CA
# 1     5100595  Christopher       Abraham   Loma Linda    CA
# 2     1902451        Elvis      Jauregui  Los Angeles    CA
# 3     1906377         Jose  Mota-Sanchez       Downey    CA
# 4     1902406      Scott        McCrorie   Long Beach    CA

# %%
print("there are :", len(df["CustomerID"].unique()) , " different customers")
# Out:
# there are : 471  different customers

# %% [markdown]
# **Question 2:** In how many different states do the customers live in?

# %%
# open file and init vars
# evaluate the contents of the file

print("Customers live in :", len(df["State"].unique()) , " states different")
# Out:
# Customers live in : 16  states different

# %%
df["State"].value_counts()
# Out:
# State
# CA               562
# NV                 8
# AZ                 6
# CA                 5
# FL                 3
# CO                 3
# NM                 3
# Ca                 2
# TX                 2
# UT                 2
# WA                 1
# NH                 1
# ID                 1
# OR                 1
# MA                 1
# IN                 1
# Name: count, dtype: int64

# %% [markdown]
# **Question 3** What is the state with most customers?

# %%
# open file and init vars
# evaluate the contents of the file

# %%
print(df["State"].value_counts().reset_index()["State"][0] , " is the state with most customers")
# Out:
# CA  is the state with most customers

# %% [markdown]
# **Question 4** What is the state with the least customers?

# %%
# open file and init vars
# evaluate the contents of the file

print(df["State"].value_counts().reset_index()["State"][15] , " is the state with least customers")
# Out:
# IN  is the state with least customers

# %%
df["State"].value_counts()
# Out:
# State
# CA               562
# NV                 8
# AZ                 6
# CA                 5
# FL                 3
# CO                 3
# NM                 3
# Ca                 2
# TX                 2
# UT                 2
# WA                 1
# NH                 1
# ID                 1
# OR                 1
# MA                 1
# IN                 1
# Name: count, dtype: int64

# %% [markdown]
# **Question 5:** What is the most common last name?

# %%
# open file and init vars
# evaluate the contents of the file


print(df["LastName"].value_counts().reset_index()["LastName"][0] , " is the common last name")
# Out:
# Smith  is the common last name

# %% [markdown]
# # Exercise 2: Processing Orders data (difficulty high)
#
# The second sample files contains orders placed by customers from the first file. Be careful, this file has many rows and you most likely should not print the contents of the whole file.
#
# The file contains the following columns: CustomerID, OrderID, Date, OrderTotal, ProductName, Price
#
# ![Data sample](https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/images/orders.png)
#
# *Hint:* We advise you to take a look at the data before you start.
# **if you want to manually take a look at the data before you start, please see the content of the data [here](https://raw.githubusercontent.com/anyoneai/notebooks/main/customers_and_orders/data/orders.csv).
#
# *Hint*: There are many ways to do this exercise you can do your own, although here's some help. You can solve this exercise reading and parsing CSV files, structuring data into dictionaries, and using for loops to navigate the contents
#
# *Hint*: Also, the data is not clean and you will have to figure out how to deal with that data from the code, without having to modify the data source.
#
#
#
# **Question #1:** How many unique orders are in the orders.csv file?
#
# **Question #2:** What is the average number of items per order (rounded to two decimal places)?
#
# **Question #3:** What is the highest number of items per order?
#
# **Question #4:** What is the number of orders placed in October 2021?
#
# **Question #5:** Which customer spent the most amount of money in 2021?
#
# **Question #6:** Historically, what is the best month for sales?
#
# Once you get your answers, remember to go back to the course and introduce them in the multiple choice quiz

# %%
# open and evaluate orders.csv

from os.path import exists
import csv

# check if file can be found and open the file
datafile = "./sample_data/orders.csv"
if not exists(datafile):
  raise SystemExit("You should run the first code cell and download the dataset files!")

# customers file is in the sample_data folder and can be opened.
# Using csv reader is one way of dealing with the file
# but it's up to you how you want to proceed
with open(datafile, 'r') as fl:
  csvreader = csv.reader(fl, delimiter=',')

  # loop through the rows and count etc. THE REST IS UP TO YOU!


print("All done!")
# Out:
# All done!

# %%
df = pd.read_csv(datafile)
df
# Out:
#        CustomerID  OrderID                     Date  OrderTotal  ProductName  \
# 0            8091  7742581  2021-07-26 14:40:10.783        95.0          Z03
# 1          902139  7742778  2021-08-08 05:01:21.120        60.0     0844 A/C
# 2         2300266  7742593  2021-07-27 11:00:16.020       185.0          M07
# 3         2300266  7742593  2021-07-27 11:00:16.020       185.0          M09
# 4         5173013  7742609  2021-07-28 14:26:13.930       165.0         0324
# ...           ...      ...                      ...         ...          ...
# 29289     5415451  7791815  2022-02-07 14:37:30.567         0.0  Circle #041
# 29290     5415483  7791820  2022-02-07 15:55:55.260       132.0         HH33
# 29291     5415485  7791822  2022-02-07 16:23:05.940       132.0         3568
# 29292     4300695  7791824  2022-02-07 16:55:33.343       157.0         0414
# 29293     5415503  7791848  2022-02-09 10:36:56.553       132.0         PP22
#
#        Price
# 0       90.0
# 1       60.0
# ...

# %%
df2
# Out:
#      CustomerID    FirstName      LastName         City State
# 0          6192        Randi    Piedrahita  Canoga Park    CA
# 1       5100595  Christopher       Abraham   Loma Linda    CA
# 2       1902451        Elvis      Jauregui  Los Angeles    CA
# 3       1906377         Jose  Mota-Sanchez       Downey    CA
# 4       1902406      Scott        McCrorie   Long Beach    CA
# ..          ...          ...           ...          ...   ...
# 597     5415365      Trinity     Hall Reif        Poway    CA
# 598     5415465       Kisona   Mialoto Jr.      Lynwood    CA
# 599     5415345     Lawrence         Zhang  Temple City    CA
# 600     5415481         John        Hughes    Round Top    TX
# 601     5415482      Phillip        Okonma  Los Angeles    CA
#
# [602 rows x 5 columns]

# %%
dataf=pd.merge(df2, df, on='CustomerID',how="left")

# %%
dataf ["cliente"]=dataf["FirstName"] + " " + dataf["LastName"]

# %%
dataf
# Out:
#        CustomerID FirstName    LastName         City State  OrderID  \
# 0            6192     Randi  Piedrahita  Canoga Park    CA  7402476
# 1            6192     Randi  Piedrahita  Canoga Park    CA  7402476
# 2            6192     Randi  Piedrahita  Canoga Park    CA  7402476
# 3            6192     Randi  Piedrahita  Canoga Park    CA  7403306
# 4            6192     Randi  Piedrahita  Canoga Park    CA  7486212
# ...           ...       ...         ...          ...   ...      ...
# 45634     5415345  Lawrence       Zhang  Temple City    CA  7791127
# 45635     5415345  Lawrence       Zhang  Temple City    CA  7791769
# 45636     5415481      John      Hughes    Round Top    TX  7791814
# 45637     5415481      John      Hughes    Round Top    TX  7791814
# 45638     5415482   Phillip      Okonma  Los Angeles    CA  7791818
#
#                           Date  OrderTotal ProductName  Price  \
# 0      2017-12-10 06:23:48.490       360.0        0235  120.0
# ...

# %%
#Question #5: Which customer spent the most amount of money in 2021?

df2021 =dataf[(dataf['Date'] >= '2021-01-01') & (dataf['Date'] < '2022-01-01')]
group=df2021.groupby(["cliente","OrderID"])["OrderTotal"].sum().sort_values(ascending=False).reset_index()

# %%
bran=df2021[df2021["FirstName"]=="Kenneth"].drop_duplicates("ProductName",keep="first").sort_values("OrderID", ascending=False)

# %%
bran["OrderTotal"].sum()
# Out:
# 292.0

# %%
group[group["cliente"]=="Brandon Divas"]
# Out:
#             cliente  OrderID  OrderTotal
# 16    Brandon Divas  7743529      6750.0
# 43    Brandon Divas  7788604      3740.0
# 44    Brandon Divas  7790462      3740.0
# 45    Brandon Divas  7742654      3740.0
# 80    Brandon Divas  7695807      2205.0
# 85    Brandon Divas  7741602      2130.0
# 86    Brandon Divas  7789484      2130.0
# 96    Brandon Divas  7740599      2100.0
# 288   Brandon Divas  7694774       970.0
# 1042  Brandon Divas  7694893       250.0
# 1096  Brandon Divas  7789483       235.0

# %%
filtered_df = group[group['cliente'].isin(["Brandon Divas"])]
filtered_df
# Out:
#          cliente  OrderTotal
# 3  Brandon Divas     27990.0

# %%
df2021[df2021["cliente"]=="Brandon Divas"]
# Out:
#        CustomerID FirstName LastName         City State  OrderID  \
# 16349     5172443   Brandon    Divas  Los Angeles    CA  7694774
# 16350     5172443   Brandon    Divas  Los Angeles    CA  7694774
# 16365     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16366     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16367     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16368     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16369     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16370     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16371     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16379     5172443   Brandon    Divas  Los Angeles    CA  7694893
# 16380     5172443   Brandon    Divas  Los Angeles    CA  7695807
# 16381     5172443   Brandon    Divas  Los Angeles    CA  7695807
# 16382     5172443   Brandon    Divas  Los Angeles    CA  7695807
# ...

# %%
df2021[df2021["cliente"]=="Brandon Divas"]
# Out:
#        CustomerID FirstName LastName         City State  OrderID  \
# 16349     5172443   Brandon    Divas  Los Angeles    CA  7694774
# 16350     5172443   Brandon    Divas  Los Angeles    CA  7694774
# 16365     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16366     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16367     5172443   Brandon    Divas  Los Angeles    CA  7741602
# 16368     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16369     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16370     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16371     5172443   Brandon    Divas  Los Angeles    CA  7742654
# 16379     5172443   Brandon    Divas  Los Angeles    CA  7694893
# 16380     5172443   Brandon    Divas  Los Angeles    CA  7695807
# 16381     5172443   Brandon    Divas  Los Angeles    CA  7695807
# 16382     5172443   Brandon    Divas  Los Angeles    CA  7695807
# ...

# %%
df2021.OrderTotal.sort_values(ascending=False)
# Out:
# 27251    2360.0
# 27253    2360.0
# 27250    2360.0
# 27249    2360.0
# 27248    2360.0
#           ...
# 37993       0.0
# 8738        0.0
# 41044       0.0
# 826         0.0
# 19048       0.0
# Name: OrderTotal, Length: 4903, dtype: float64

# %%
#Question #5: Which customer spent the most amount of money in 2021?
df2021 = df[(df['Date'] >= '2021-01-01') & (df['Date'] < '2022-01-01')].groupby('CustomerID')['OrderTotal'].sum().sort_values(ascending=False).reset_index().head(1)
df2021

#print("The customer who spent the most amount of money in 2021 was CustomerID: ",df2021.CustomerID[0] , "with ",df2021.OrderTotal[0], " items")
# Out:
#    CustomerID  OrderTotal
# 0        5464     56170.0

# %%
#Question #1: How many unique orders are in the orders.csv file?
print("there are :", len(df["OrderID"].unique()) , " different orders")
# Out:
# there are : 16672  different orders

# %%
#Question #2: What is the average number of items per order (rounded to two decimal places)?
print("there are in mean ",round(df["OrderID"].value_counts().mean(),2) , " items per order")
# Out:
# there are in mean  1.76  items per order

# %%
#Question #3: What is the highest number of items per order?
# Out:
# The highest number of items per order are  95.0

# %%
df.groupby("OrderID")["OrderTotal"].count().sort_values(ascending=False).reset_index().head(1)
# Out:
#    OrderID  OrderTotal
# 0  5802666          35

# %%
#Question #4: What is the number of orders placed in October 2021?
df102021 = df[(df['Date'] >= '2021-10-01') & (df['Date'] < '2021-11-01')]['OrderID'].nunique()
print("The number of orders placed in October 2021 are ",df102021)
# Out:
# The number of orders placed in October 2021 are  267

# %%
#Question #5: Which customer spent the most amount of money in 2021?
df2021 = df[(df['Date'] >= '2021-01-01') & (df['Date'] < '2022-01-01')].groupby('CustomerID')['OrderTotal'].sum().sort_values(ascending=False).reset_index().head(1)
df2021

#print("The customer who spent the most amount of money in 2021 was CustomerID: ",df2021.CustomerID[0] , "with ",df2021.OrderTotal[0], " items")
# Out:
#    CustomerID  OrderTotal
# 0        5464     56170.0

# %%
dataf['Month'] = pd.DatetimeIndex(dataf['Date']).month

# %%
dataf

# %%
dataf.groupby('Month')['OrderTotal'].sum().sort_values(ascending=False).reset_index()
# Out:
#     Month  OrderTotal
# 0     1.0   1252836.0
# 1     2.0   1251589.0
# 2     6.0   1138055.0
# 3     5.0   1087315.0
# 4    11.0   1059573.0
# 5     9.0   1022882.0
# 6    10.0    992446.0
# 7     4.0    937753.0
# 8     7.0    872820.0
# 9     8.0    846503.0
# 10    3.0    826450.0
# 11   12.0    824101.0

# %%
dataf.groupby('Month')['OrderTotal'].sum().sort_values(ascending=False).reset_index().head(1)["Month"][0]
# Out:
# 1.0

# %%
#Question #6: Historically, what is the best month for sales?
df['Month'] = pd.DatetimeIndex(df['Date']).month

print("The best month for sales is ", df.groupby('Month')['OrderTotal'].sum().sort_values(ascending=False).reset_index().head(1)["Month"][0] )
print("1 is January" )
# Out:
# The best month for sales is  1.0
# 1 is January

# %% [markdown]
# # Finished!
#
# Hope this was not too difficult and slicing and dicing the datasets was some fun. Now head on back to the course and provide the answers to the questions from this exercise.
